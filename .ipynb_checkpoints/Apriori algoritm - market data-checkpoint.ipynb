# %% [markdown]
# # APRIORI ALGORITHM - Market basket data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("market_basket.csv",header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
#!pip install apyori

# %%
# Data Processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset
from apyori import apriori
rules = apriori(transactions ,
              min_support = 0.003 ,     #(3items * 7 days in week)/(Total Rows in dataset 7501)
              min_confidence = 0.2 ,
              min_lift = 3 ,
              min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0 , len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
#a

# %%
result
# Out:
# [['light cream', 'chicken'],
#  ['mushroom cream sauce', 'escalope'],
#  ['pasta', 'escalope'],
#  ['fromage blanc', 'honey'],
#  ['herb & pepper', 'ground beef'],
#  ['tomato sauce', 'ground beef'],
#  ['light cream', 'olive oil'],
#  ['olive oil', 'whole wheat pasta'],
#  ['pasta', 'shrimp'],
#  ['milk', 'avocado', 'spaghetti'],
#  ['milk', 'cake', 'burgers'],
#  ['chocolate', 'turkey', 'burgers'],
#  ['milk', 'turkey', 'burgers'],
#  ['tomatoes', 'frozen vegetables', 'cake'],
#  ['spaghetti', 'cereals', 'ground beef'],
#  ['milk', 'ground beef', 'chicken'],
#  ['light cream', 'nan', 'chicken'],
#  ['milk', 'olive oil', 'chicken'],
#  ['olive oil', 'spaghetti', 'chicken'],
#  ['chocolate', 'frozen vegetables', 'shrimp'],
#  ['chocolate', 'herb & pepper', 'ground beef'],
#  ['chocolate', 'milk', 'soup'],
#  ['ground beef', 'spaghetti', 'cooking oil'],
#  ['eggs', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'eggs', 'red wine'],
#  ['mushroom cream sauce', 'nan', 'escalope'],
#  ['pasta', 'nan', 'escalope'],
#  ['french fries', 'herb & pepper', 'ground beef'],
#  ['fromage blanc', 'nan', 'honey'],
#  ['green tea', 'tomatoes', 'frozen vegetables'],
#  ['frozen vegetables', 'spaghetti', 'ground beef'],
#  ['milk', 'frozen vegetables', 'olive oil'],
#  ['milk', 'frozen vegetables', 'soup'],
#  ['milk', 'tomatoes', 'frozen vegetables'],
#  ['frozen vegetables', 'shrimp', 'mineral water'],
#  ['olive oil', 'frozen vegetables', 'spaghetti'],
#  ['frozen vegetables', 'shrimp', 'spaghetti'],
#  ['tomatoes', 'frozen vegetables', 'shrimp'],
#  ['tomatoes', 'frozen vegetables', 'spaghetti'],
#  ['ground beef', 'spaghetti', 'grated cheese'],
#  ['green tea', 'tomatoes', 'ground beef'],
#  ['milk', 'herb & pepper', 'ground beef'],
#  ['herb & pepper', 'ground beef', 'mineral water'],
#  ['nan', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'herb & pepper', 'ground beef'],
#  ['milk', 'olive oil', 'ground beef'],
#  ['milk', 'soup', 'ground beef'],
#  ['tomato sauce', 'nan', 'ground beef'],
#  ['pepper', 'spaghetti', 'ground beef'],
#  ['shrimp', 'ground beef', 'spaghetti'],
#  ['tomato sauce', 'spaghetti', 'ground beef'],
#  ['light cream', 'spaghetti', 'mineral water'],
#  ['light cream', 'nan', 'olive oil'],
#  ['milk', 'shrimp', 'olive oil'],
#  ['milk', 'olive oil', 'soup'],
#  ['milk', 'spaghetti', 'olive oil'],
#  ['milk', 'tomatoes', 'soup'],
#  ['milk', 'spaghetti', 'whole wheat pasta'],
#  ['olive oil', 'soup', 'mineral water'],
#  ['olive oil', 'whole wheat pasta', 'mineral water'],
#  ['olive oil', 'nan', 'whole wheat pasta'],
#  ['pasta', 'nan', 'shrimp'],
#  ['olive oil', 'spaghetti', 'pancakes'],
#  ['olive oil', 'tomatoes', 'spaghetti'],
#  ['tomatoes', 'spaghetti', 'whole wheat rice'],
#  ['milk', 'avocado', 'nan', 'spaghetti'],
#  ['milk', 'cake', 'nan', 'burgers'],
#  ['chocolate', 'nan', 'turkey', 'burgers'],
#  ['milk', 'nan', 'turkey', 'burgers'],
#  ['tomatoes', 'frozen vegetables', 'cake', 'nan'],
#  ['nan', 'spaghetti', 'cereals', 'ground beef'],
#  ['milk', 'ground beef', 'nan', 'chicken'],
#  ['milk', 'nan', 'olive oil', 'chicken'],
#  ['olive oil', 'nan', 'spaghetti', 'chicken'],
#  ['chocolate', 'eggs', 'ground beef', 'mineral water'],
#  ['chocolate', 'frozen vegetables', 'ground beef', 'mineral water'],
#  ['chocolate', 'frozen vegetables', 'spaghetti', 'ground beef'],
#  ['chocolate', 'frozen vegetables', 'milk', 'mineral water'],
#  ['chocolate', 'frozen vegetables', 'milk', 'spaghetti'],
#  ['chocolate', 'frozen vegetables', 'shrimp', 'mineral water'],
#  ['chocolate', 'frozen vegetables', 'nan', 'shrimp'],
#  ['chocolate', 'nan', 'herb & pepper', 'ground beef'],
#  ['chocolate', 'nan', 'milk', 'soup'],
#  ['chocolate', 'spaghetti', 'olive oil', 'mineral water'],
#  ['chocolate', 'shrimp', 'spaghetti', 'mineral water'],
#  ['ground beef', 'nan', 'spaghetti', 'cooking oil'],
#  ['milk', 'frozen vegetables', 'eggs', 'mineral water'],
#  ['nan', 'eggs', 'herb & pepper', 'ground beef'],
#  ['nan', 'spaghetti', 'eggs', 'red wine'],
#  ['french fries', 'nan', 'herb & pepper', 'ground beef'],
#  ['milk', 'spaghetti', 'frozen smoothie', 'mineral water'],
#  ['green tea', 'tomatoes', 'frozen vegetables', 'nan'],
#  ['milk', 'frozen vegetables', 'ground beef', 'mineral water'],
#  ['milk', 'frozen vegetables', 'spaghetti', 'ground beef'],
#  ['frozen vegetables', 'spaghetti', 'ground beef', 'mineral water'],
#  ['frozen vegetables', 'nan', 'ground beef', 'spaghetti'],
#  ['milk', 'frozen vegetables', 'olive oil', 'mineral water'],
#  ['milk', 'frozen vegetables', 'soup', 'mineral water'],
#  ['milk', 'frozen vegetables', 'spaghetti', 'mineral water'],
#  ['milk', 'frozen vegetables', 'nan', 'olive oil'],
#  ['milk', 'frozen vegetables', 'nan', 'soup'],
#  ['milk', 'tomatoes', 'frozen vegetables', 'nan'],
#  ['frozen vegetables', 'nan', 'shrimp', 'mineral water'],
#  ['frozen vegetables', 'shrimp', 'spaghetti', 'mineral water'],
#  ['tomatoes', 'frozen vegetables', 'spaghetti', 'mineral water'],
#  ['olive oil', 'frozen vegetables', 'nan', 'spaghetti'],
#  ['frozen vegetables', 'nan', 'shrimp', 'spaghetti'],
#  ['tomatoes', 'frozen vegetables', 'nan', 'shrimp'],
#  ['tomatoes', 'frozen vegetables', 'nan', 'spaghetti'],
#  ['ground beef', 'nan', 'spaghetti', 'grated cheese'],
#  ['green tea', 'tomatoes', 'nan', 'ground beef'],
#  ['milk', 'nan', 'herb & pepper', 'ground beef'],
#  ['nan', 'herb & pepper', 'ground beef', 'mineral water'],
#  ['nan', 'spaghetti', 'herb & pepper', 'ground beef'],
#  ['milk', 'spaghetti', 'ground beef', 'mineral water'],
#  ['milk', 'nan', 'olive oil', 'ground beef'],
#  ['milk', 'nan', 'soup', 'ground beef'],
#  ['olive oil', 'spaghetti', 'ground beef', 'mineral water'],
#  ['spaghetti', 'pancakes', 'ground beef', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'ground beef', 'mineral water'],
#  ['nan', 'spaghetti', 'pepper', 'ground beef'],
#  ['nan', 'shrimp', 'ground beef', 'spaghetti'],
#  ['tomato sauce', 'nan', 'spaghetti', 'ground beef'],
#  ['light cream', 'nan', 'spaghetti', 'mineral water'],
#  ['milk', 'spaghetti', 'olive oil', 'mineral water'],
#  ['milk', 'tomatoes', 'spaghetti', 'mineral water'],
#  ['milk', 'nan', 'shrimp', 'olive oil'],
#  ['milk', 'nan', 'olive oil', 'soup'],
#  ['milk', 'nan', 'spaghetti', 'olive oil'],
#  ['milk', 'tomatoes', 'nan', 'soup'],
#  ['milk', 'nan', 'spaghetti', 'whole wheat pasta'],
#  ['olive oil', 'nan', 'soup', 'mineral water'],
#  ['olive oil', 'nan', 'whole wheat pasta', 'mineral water'],
#  ['olive oil', 'nan', 'spaghetti', 'pancakes'],
#  ['olive oil', 'tomatoes', 'nan', 'spaghetti'],
#  ['tomatoes', 'nan', 'spaghetti', 'whole wheat rice'],
#  ['nan', 'eggs', 'chocolate', 'ground beef', 'mineral water'],
#  ['nan', 'chocolate', 'frozen vegetables', 'ground beef', 'mineral water'],
#  ['nan', 'chocolate', 'frozen vegetables', 'spaghetti', 'ground beef'],
#  ['nan', 'chocolate', 'milk', 'frozen vegetables', 'mineral water'],
#  ['nan', 'chocolate', 'milk', 'frozen vegetables', 'spaghetti'],
#  ['nan', 'chocolate', 'frozen vegetables', 'shrimp', 'mineral water'],
#  ['olive oil', 'nan', 'chocolate', 'spaghetti', 'mineral water'],
#  ['nan', 'chocolate', 'shrimp', 'spaghetti', 'mineral water'],
#  ['nan', 'eggs', 'milk', 'frozen vegetables', 'mineral water'],
#  ['nan', 'milk', 'spaghetti', 'frozen smoothie', 'mineral water'],
#  ['nan', 'milk', 'frozen vegetables', 'ground beef', 'mineral water'],
#  ['nan', 'milk', 'frozen vegetables', 'spaghetti', 'ground beef'],
#  ['nan', 'frozen vegetables', 'spaghetti', 'ground beef', 'mineral water'],
#  ['olive oil', 'nan', 'milk', 'frozen vegetables', 'mineral water'],
#  ['nan', 'milk', 'frozen vegetables', 'soup', 'mineral water'],
#  ['nan', 'milk', 'frozen vegetables', 'spaghetti', 'mineral water'],
#  ['nan', 'frozen vegetables', 'spaghetti', 'shrimp', 'mineral water'],
#  ['nan', 'frozen vegetables', 'tomatoes', 'spaghetti', 'mineral water'],
#  ['nan', 'milk', 'spaghetti', 'ground beef', 'mineral water'],
#  ['olive oil', 'nan', 'spaghetti', 'ground beef', 'mineral water'],
#  ['nan', 'spaghetti', 'pancakes', 'ground beef', 'mineral water'],
#  ['nan', 'tomatoes', 'spaghetti', 'ground beef', 'mineral water'],
#  ['olive oil', 'nan', 'milk', 'spaghetti', 'mineral water'],
#  ['nan', 'milk', 'tomatoes', 'spaghetti', 'mineral water']]
